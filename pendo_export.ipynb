# %%
import requests
import json
import pandas as pd
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None
import numpy as np
import datetime
from datetime import date
from datetime import datetime
import time
from urllib.request import Request, urlopen

import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.client import GoogleCredentials
from google.oauth2.service_account import Credentials

scopes = ['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive']

credentials = {
  "type": "service_account",
  "project_id": "grow-data-303020",
  "private_key_id": "ce81c41081c91921236f8a7bb465b3efad83046d",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "grow-data@grow-data-303020.iam.gserviceaccount.com",
  "client_id": "105922171076484017051",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/grow-data%40grow-data-303020.iam.gserviceaccount.com"
}
gc = gspread.service_account_from_dict(credentials)

# %%
# https://engageapi.pendo.io/#2757f228-ca94-4075-a840-b1fafd6d43b2

# %%
pendo_api = 'dd500e10-a474-469e-41c5-739d0f694849.us'

# %%
url = 'https://app.pendo.io/api/v1/feature'
headers = {
    'Content-Type': 'application/json',
    'x-pendo-integration-key': pendo_api
}
# params = {'id': '{featureId}'}

response = requests.get(url, headers=headers)

# %%
pd.DataFrame(response.json())
# Out:
#                                         createdByUser      createdAt  \
# 0   {'id': '6327515257831424', 'username': 'wassim...  1671503928637
# 1   {'id': '5376494346829824', 'username': 'michae...  1662999018896
# 2   {'id': '5376494346829824', 'username': 'michae...  1652206642252
# 3   {'id': '5376494346829824', 'username': 'michae...  1650052415315
# 4   {'id': '5376494346829824', 'username': 'michae...  1642623472937
# ..                                                ...            ...
# 61  {'id': '5685608585428992', 'username': 'sophie...  1673555508249
# 62  {'id': '5685608585428992', 'username': 'sophie...  1673555480900
# 63  {'id': '5685608585428992', 'username': 'sophie...  1673555453124
# 64  {'id': '5685608585428992', 'username': 'sophie...  1673555535990
# 65  {'id': '5685608585428992', 'username': 'sophie...  1673372211440
#
#                                     lastUpdatedByUser  lastUpdatedAt     kind  \
# 0   {'id': '6327515257831424', 'username': 'wassim...  1671503928637  Feature
# 1   {'id': '5376494346829824', 'username': 'michae...  1662999018896  Feature
# 2   {'id': '5376494346829824', 'username': 'michae...  1652206642252  Feature
# 3   {'id': '5376494346829824', 'username': 'michae...  1652206510155  Feature
# 4   {'id': '5376494346829824', 'username': 'michae...  1642623472937  Feature
# ..                                                ...            ...      ...
# 61  {'id': '5685608585428992', 'username': 'sophie...  1673555508249  Feature
# 62  {'id': '5685608585428992', 'username': 'sophie...  1673555480900  Feature
# 63  {'id': '5685608585428992', 'username': 'sophie...  1673555453124  Feature
# 64  {'id': '5685608585428992', 'username': 'sophie...  1673555535990  Feature
# 65  {'id': '5685608585428992', 'username': 'sophie...  1673372211440  Feature
#
#                   rootVersionId  \
# 0   bw9kYWmdPW_ir6aftePlAY4p_E4
# 1   o1m47-tl64MgmvvNmMEFw9m58l8
# 2   L8XDyxgBWoKefPfENdjaxeLuJ6k
# 3   YbVzWpv7YJpiGE7OWQRnHmFGqzo
# 4   PeNnqeDqn82RIs3b2Q7zA8v86og
# ..                          ...
# 61  ifkrxVRF6Tm4ry8pgPjJ_PiDrRA
# 62  7JNDwZDtDAzmVzAshQnfnddbBc0
# 63  tevpVEhoHq8jLg3mWlRoSdKMEjU
# 64  _jJo0gIp7xTxu6p_-pIkV2wdTng
# 65  xZ_e3SiYdU0GiHrtssZ5Qoo7pAA
#
#                                       stableVersionId  \
# 0   bw9kYWmdPW_ir6aftePlAY4p_E4-20221220023848.647...
# 1   o1m47-tl64MgmvvNmMEFw9m58l8-20220912161018.915...
# 2   L8XDyxgBWoKefPfENdjaxeLuJ6k-20220510181722.265...
# 3   YbVzWpv7YJpiGE7OWQRnHmFGqzo-20220510181510.181...
# 4   PeNnqeDqn82RIs3b2Q7zA8v86og-20220119201752.942...
# ..                                                ...
# 61  ifkrxVRF6Tm4ry8pgPjJ_PiDrRA-20230112203148.255...
# 62  7JNDwZDtDAzmVzAshQnfnddbBc0-20230112203120.909...
# 63  tevpVEhoHq8jLg3mWlRoSdKMEjU-20230112203053.132...
# 64  _jJo0gIp7xTxu6p_-pIkV2wdTng-20230112203215.999...
# 65  xZ_e3SiYdU0GiHrtssZ5Qoo7pAA-20230110173651.448...
#
#                              id   appId  \
# 0   bw9kYWmdPW_ir6aftePlAY4p_E4 -323232
# 1   o1m47-tl64MgmvvNmMEFw9m58l8 -323232
# 2   L8XDyxgBWoKefPfENdjaxeLuJ6k -323232
# 3   YbVzWpv7YJpiGE7OWQRnHmFGqzo -323232
# 4   PeNnqeDqn82RIs3b2Q7zA8v86og -323232
# ..                          ...     ...
# 61  ifkrxVRF6Tm4ry8pgPjJ_PiDrRA -323232
# 62  7JNDwZDtDAzmVzAshQnfnddbBc0 -323232
# 63  tevpVEhoHq8jLg3mWlRoSdKMEjU -323232
# 64  _jJo0gIp7xTxu6p_-pIkV2wdTng -323232
# 65  xZ_e3SiYdU0GiHrtssZ5Qoo7pAA -323232
#
#                                           name color  \
# 0                      Adding a new Automation
# 1                            Cortex Nav Switch
# 2   Courses: Change Technology (new - 5/10/22)
# 3             Courses: Change Technology (old)
# 4                      Courses: Course Created
# ..                                         ...   ...
# 61         Workspaces: Retention [Automations]
# 62            Workspaces: Retention [Insights]
# 63            Workspaces: Retention [Overview]
# 64            Workspaces: Retention [Settings]
# 65              Workspaces: Retention Dropdown
#
#                                                 group  isCoreEvent  \
# 0   {'id': 'wM4_-J9wj7sczZtRMg_PD9kCif8', 'name': ...        False
# 1   {'id': 'wM4_-J9wj7sczZtRMg_PD9kCif8', 'name': ...        False
# 2   {'id': '_PENDO_DEFAULTGROUP_03_', 'name': 'Att...        False
# 3   {'id': '_PENDO_DEFAULTGROUP_03_', 'name': 'Att...        False
# 4   {'id': '_PENDO_DEFAULTGROUP_02_', 'name': 'Sch...         True
# ..                                                ...          ...
# 61  {'id': 'wM4_-J9wj7sczZtRMg_PD9kCif8', 'name': ...        False
# 62  {'id': 'wM4_-J9wj7sczZtRMg_PD9kCif8', 'name': ...        False
# 63  {'id': 'wM4_-J9wj7sczZtRMg_PD9kCif8', 'name': ...        False
# 64  {'id': 'wM4_-J9wj7sczZtRMg_PD9kCif8', 'name': ...        False
# 65  {'id': 'wM4_-J9wj7sczZtRMg_PD9kCif8', 'name': ...        False
#
#      validThrough  dirty  dailyMergeFirst  dailyRollupFirst  \
# 0   1673553600000  False                0                 0
# 1   1673553600000  False                0                 0
# 2   1673553600000  False                0                 0
# 3   1673553600000  False                0                 0
# 4   1673553600000  False                0                 0
# ..            ...    ...              ...               ...
# 61  1673553600000  False                0                 0
# 62  1673553600000  False                0                 0
# 63  1673553600000  False                0                 0
# 64  1673553600000  False                0                 0
# 65  1673553600000  False                0                 0
#
#    createdDesignerVersion eventPropertyConfigurations elementInitialTag  \
# 0                   4.2.3                          []            BUTTON
# 1                   4.2.3                          []            BUTTON
# 2                   4.2.3                          []            BUTTON
# 3                   4.2.3                          []                LI
# 4                   4.2.3                          []            BUTTON
# ..                    ...                         ...               ...
# 61                  4.2.3                          []                 A
# 62                  4.2.3                          []                 A
# 63                  4.2.3                          []                 A
# 64                  4.2.3                          []                 A
# 65                  4.2.3                          []                 A
#
#                                      elementPathRules elementSelectionType  \
# 0                              [.MuiButton-contained]            suggested
# 1   [.MuiTypography-subtitle1:contains('Switch Nav...            suggested
# 2                                   [.MuiButton-root]            suggested
# 3   [.MuiMenuItem-root:contains('Change Technology')]            suggested
# 4           [.MuiButton-contained:contains('Submit')]            suggested
# ..                                                ...                  ...
# 61           [[data-pendoid="retention_automations"]]            suggested
# 62              [[data-pendoid="retention_insights"]]            suggested
# 63              [[data-pendoid="retention_overview"]]            suggested
# 64              [[data-pendoid="retention_settings"]]            suggested
# 65              [[data-pendoid="dropdown_retention"]]               custom
#
#                                      suggestedMatch  appWide  \
# 0                              .MuiButton-contained     True
# 1      .MuiToolbar-root > div > .MuiIconButton-root     True
# 2                                   .MuiButton-root    False
# 3   .MuiMenuItem-root:contains('Change Technology')    False
# 4           .MuiButton-contained:contains('Submit')    False
# ..                                              ...      ...
# 61           [data-pendoid="retention_automations"]     True
# 62              [data-pendoid="retention_insights"]     True
# 63              [data-pendoid="retention_overview"]     True
# 64              [data-pendoid="retention_settings"]     True
# 65                           [href="/workspaces/4"]     True
#
#                          pageId
# 0                           NaN
# 1                           NaN
# 2   FGD6I1BYuOkSgceU-LwzRuVRzcM
# 3   3aF2lGBOCv3girf9-CIcEf3nd5s
# 4   4gpcC7yUgrw6nrwYxQ9kH9vOupI
# ..                          ...
# 61                          NaN
# 62                          NaN
# 63                          NaN
# 64                          NaN
# 65                          NaN
#
# [66 rows x 25 columns]
